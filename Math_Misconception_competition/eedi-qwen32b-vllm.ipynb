# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("aerdem4/logits-processor-zoo")
path1 = kagglehub.dataset_download("nbroad/hf-libraries")

print("Path to dataset files:", path1)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/nbroad/hf-libraries?dataset_version_number=224...
#   9%|▉         | 93.0M/1.02G [00:15<02:34, 6.46MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("aerdem4/logits-processor-zoo")
# ----> 5 path1 = kagglehub.dataset_download("nbroad/hf-libraries")
#       7 print("Path to dataset files:", path1)
#
# File ~/anaconda3/envs/kernel1/lib/python3.12/site-packages/kagglehub/datasets.py:28, in dataset_download(handle, path, force_download)
#      26 h = parse_dataset_handle(handle)
#      27 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 28 return registry.dataset_resolver(h, path, force_download=force_download)
#
# File ~/anaconda3/envs/kernel1/lib/python3.12/site-packages/kagglehub/registry.py:23, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      21 for impl in reversed(self._impls):
#      22     if impl.is_supported(*args, **kwargs):
# ---> 23         return impl(*args, **kwargs)
#      24     else:
#      25         fails.append(type(impl).__name__)
#
# File ~/anaconda3/envs/kernel1/lib/python3.12/site-packages/kagglehub/http_resolver.py:125, in DatasetHttpResolver.__call__(self, h, path, force_download)
#     122 os.makedirs(os.path.dirname(archive_path), exist_ok=True)
#     124 # First, we download the archive.
# --> 125 api_client.download_file(url_path, archive_path, h)
#     127 # Create the directory to extract the archive to.
#     128 os.makedirs(out_path, exist_ok=True)
#
# File ~/anaconda3/envs/kernel1/lib/python3.12/site-packages/kagglehub/clients.py:191, in KaggleApiV1Client.download_file(self, path, out_file, resource_handle, cached_path)
#     189 else:
#     190     logger.info(f"Downloading from {url}...")
# --> 191     _download_file(response, out_file, size_read, total_size, hash_object)
#     193 if hash_object:
#     194     actual_md5_hash = to_b64_digest(hash_object)
#
# File ~/anaconda3/envs/kernel1/lib/python3.12/site-packages/kagglehub/clients.py:231, in _download_file(response, out_file, size_read, total_size, hash_object)
#     229 with tqdm(total=total_size, initial=size_read, unit="B", unit_scale=True, unit_divisor=1024) as progress_bar:
#     230     with open(out_file, open_mode) as f:
# --> 231         for chunk in response.iter_content(CHUNK_SIZE):
#     232             f.write(chunk)
#     233             if hash_object:
#
# File ~/anaconda3/envs/kernel1/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/anaconda3/envs/kernel1/lib/python3.12/site-packages/urllib3/response.py:1060, in HTTPResponse.stream(self, amt, decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1060         data = self.read(amt=amt, decode_content=decode_content)
#    1062         if data:
#    1063             yield data
#
# File ~/anaconda3/envs/kernel1/lib/python3.12/site-packages/urllib3/response.py:949, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     946     if len(self._decoded_buffer) >= amt:
#     947         return self._decoded_buffer.get(amt)
# --> 949 data = self._raw_read(amt)
#     951 flush_decoder = amt is None or (amt != 0 and not data)
#     953 if not data and len(self._decoded_buffer) == 0:
#
# File ~/anaconda3/envs/kernel1/lib/python3.12/site-packages/urllib3/response.py:873, in HTTPResponse._raw_read(self, amt, read1)
#     870 fp_closed = getattr(self._fp, "closed", False)
#     872 with self._error_catcher():
# --> 873     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     874     if amt is not None and amt != 0 and not data:
#     875         # Platform-specific: Buggy versions of Python.
#     876         # Close the connection when no data is returned
#    (...)
#     881         # not properly close the connection in all cases. There is
#     882         # no harm in redundantly calling close.
#     883         self._fp.close()
#
# File ~/anaconda3/envs/kernel1/lib/python3.12/site-packages/urllib3/response.py:856, in HTTPResponse._fp_read(self, amt, read1)
#     853     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     854 else:
#     855     # StringIO doesn't like amt=None
# --> 856     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/anaconda3/envs/kernel1/lib/python3.12/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File ~/anaconda3/envs/kernel1/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~/anaconda3/envs/kernel1/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/kernel1/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# %%time
# !pip uninstall -y torch
# !pip install -q --no-index --find-links=/kaggle/input/making-wheels-of-necessary-packages-for-vllm vllm
# !pip install -q -U /kaggle/input/vllm-t4-fix/grpcio-1.62.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# !pip install -q -U /kaggle/input/vllm-t4-fix/ray-2.11.0-cp310-cp310-manylinux2014_x86_64.whl
# !pip install -q --no-deps --no-index /kaggle/input/hf-libraries/sentence-transformers/sentence_transformers-3.1.0-py3-none-any.whl
# !pip install --no-deps --no-index /Users/idrissamahamoudoudicko/.cache/kagglehub/datasets/aerdem4/logits-processor-zoo-0.1.0-py3-none-any.whl
# Out:
# WARNING: Skipping torch as it is not installed.
# WARNING: Location '/kaggle/input/making-wheels-of-necessary-packages-for-vllm' is ignored: it is either a non-existing path or lacks a specific scheme.
# ERROR: Could not find a version that satisfies the requirement vllm (from versions: none)
# ERROR: No matching distribution found for vllm
# WARNING: Requirement '/kaggle/input/vllm-t4-fix/grpcio-1.62.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl' looks like a filename, but the file does not exist
# ERROR: grpcio-1.62.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl is not a supported wheel on this platform.
# WARNING: Requirement '/kaggle/input/vllm-t4-fix/ray-2.11.0-cp310-cp310-manylinux2014_x86_64.whl' looks like a filename, but the file does not exist
# ERROR: ray-2.11.0-cp310-cp310-manylinux2014_x86_64.whl is not a supported wheel on this platform.
# WARNING: Requirement '/kaggle/input/hf-libraries/sentence-transformers/sentence_transformers-3.1.0-py3-none-any.whl' looks like a filename, but the file does not exist
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/kaggle/input/hf-libraries/sentence-transformers/sentence_transformers-3.1.0-py3-none-any.whl'
#
# WARNING: Requirement '/kaggle/input/logits-processor-zoo/logits_processor_zoo-0.1.0-py3-none-any.whl' looks like a filename, but the file does not exist
# Processing /kaggle/input/logits-processor-zoo/logits_processor_zoo-0.1.0-py3-none-any.whl
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/kaggle/input/logits-processor-zoo/logits_processor_zoo-0.1.0-py3-none-any.whl'
#
# CPU times: user 19.7 ms, sys: 26.1 ms, total: 45.8 ms
# Wall time: 3.27 s

# %%
# !pip install transformers peft accelerate \
    -q -U --no-index --find-links /kaggle/input/lmsys-wheel-files

# %%
# %%capture
# !pip install --no-index /kaggle/input/bitsandbytes0-42-0/bitsandbytes-0.42.0-py3-none-any.whl --find-links=/kaggle/input/bitsandbytes0-42-0
# !pip install --no-index  /kaggle/input/bitsandbytes0-42-0/optimum-1.21.2-py3-none-any.whl --find-links=/kaggle/input/bitsandbytes0-42-0
# !pip install --no-index  /kaggle/input/bitsandbytes0-42-0/auto_gptq-0.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl --find-links=/kaggle/input/bitsandbytes0-42-0

# %% [markdown]
# # Retrieval using 7B LLM
# Taken from: https://www.kaggle.com/code/sayoulala/use-llm-embedding-recall-infer

# %%
import pandas as pd

full_df = pd.read_csv("/kaggle/input/eedi-mining-misconceptions-in-mathematics/train.csv")


rows = []
for idx, row in full_df.iterrows():
    for option in ["A", "B", "C", "D"]:
        if option == row.CorrectAnswer:
            continue
            
        correct_answer = row[f"Answer{row.CorrectAnswer}Text"]

        query_text =f"###question###:{row['SubjectName']}-{row['ConstructName']}-{row['QuestionText']}\n###Correct Answer###:{correct_answer}\n###Misconcepte Incorrect answer###:{option}.{row[f'Answer{option}Text']}"

        rows.append({"query_text": query_text, 
                     "QuestionId_Answer": f"{row.QuestionId}_{option}",
                     "ConstructName": row.ConstructName,
                     "SubjectName": row.SubjectName,
                     "QuestionText": row.QuestionText,
                     "correct_answer": correct_answer,
                     "incorrect_answer": row[f"Answer{option}Text"]
                     })

df = pd.DataFrame(rows)
df[:50]
# Out:
#                                            query_text QuestionId_Answer  \
# 0   ###question###:BIDMAS-Use the order of operati...               0_B
# 1   ###question###:BIDMAS-Use the order of operati...               0_C
# 2   ###question###:BIDMAS-Use the order of operati...               0_D
# 3   ###question###:Simplifying Algebraic Fractions...               1_A
# 4   ###question###:Simplifying Algebraic Fractions...               1_B
# 5   ###question###:Simplifying Algebraic Fractions...               1_C
# 6   ###question###:Range and Interquartile Range f...               2_A
# 7   ###question###:Range and Interquartile Range f...               2_C
# 8   ###question###:Range and Interquartile Range f...               2_D
# 9   ###question###:Properties of Quadrilaterals-Re...               3_A
# 10  ###question###:Properties of Quadrilaterals-Re...               3_B
# 11  ###question###:Properties of Quadrilaterals-Re...               3_D
# 12  ###question###:Substitution into Formula-Subst...               4_B
# 13  ###question###:Substitution into Formula-Subst...               4_C
# 14  ###question###:Substitution into Formula-Subst...               4_D
# 15  ###question###:Area of Simple Shapes-Identify ...               5_A
# 16  ###question###:Area of Simple Shapes-Identify ...               5_B
# 17  ###question###:Area of Simple Shapes-Identify ...               5_C
# 18  ###question###:Converting between Fractions an...               6_A
# 19  ###question###:Converting between Fractions an...               6_C
# 20  ###question###:Converting between Fractions an...               6_D
# 21  ###question###:Multiplying and Dividing with D...               7_B
# 22  ###question###:Multiplying and Dividing with D...               7_C
# 23  ###question###:Multiplying and Dividing with D...               7_D
# 24  ###question###:Adding and Subtracting Fraction...               8_B
# 25  ###question###:Adding and Subtracting Fraction...               8_C
# 26  ###question###:Adding and Subtracting Fraction...               8_D
# 27  ###question###:Transformations of functions in...               9_A
# 28  ###question###:Transformations of functions in...               9_B
# 29  ###question###:Transformations of functions in...               9_D
# 30  ###question###:Expanding Triple Brackets and m...              10_A
# 31  ###question###:Expanding Triple Brackets and m...              10_C
# 32  ###question###:Expanding Triple Brackets and m...              10_D
# 33  ###question###:Nets-Identify the net of a non-...              11_A
# 34  ###question###:Nets-Identify the net of a non-...              11_B
# 35  ###question###:Nets-Identify the net of a non-...              11_C
# 36  ###question###:Angle Facts with Parallel Lines...              12_B
# 37  ###question###:Angle Facts with Parallel Lines...              12_C
# 38  ###question###:Angle Facts with Parallel Lines...              12_D
# 39  ###question###:Time-Convert from hours to minu...              13_A
# 40  ###question###:Time-Convert from hours to minu...              13_C
# 41  ###question###:Time-Convert from hours to minu...              13_D
# 42  ###question###:Trial and Improvement and Itera...              14_A
# 43  ###question###:Trial and Improvement and Itera...              14_B
# 44  ###question###:Trial and Improvement and Itera...              14_C
# 45  ###question###:Area of Simple Shapes-Calculate...              15_A
# 46  ###question###:Area of Simple Shapes-Calculate...              15_B
# 47  ###question###:Area of Simple Shapes-Calculate...              15_C
# 48  ###question###:Sharing in a Ratio-Divide a qua...              16_A
# 49  ###question###:Sharing in a Ratio-Divide a qua...              16_B
#
#                                         ConstructName  \
# 0   Use the order of operations to carry out calcu...
# 1   Use the order of operations to carry out calcu...
# 2   Use the order of operations to carry out calcu...
# 3   Simplify an algebraic fraction by factorising ...
# 4   Simplify an algebraic fraction by factorising ...
# 5   Simplify an algebraic fraction by factorising ...
# 6             Calculate the range from a list of data
# 7             Calculate the range from a list of data
# 8             Calculate the range from a list of data
# 9   Recall and use the intersecting diagonals prop...
# 10  Recall and use the intersecting diagonals prop...
# 11  Recall and use the intersecting diagonals prop...
# 12  Substitute positive integer values into formul...
# 13  Substitute positive integer values into formul...
# 14  Substitute positive integer values into formul...
# 15                            Identify a unit of area
# 16                            Identify a unit of area
# 17                            Identify a unit of area
# 18  Convert two digit integer percentages to fract...
# 19  Convert two digit integer percentages to fract...
# 20  Convert two digit integer percentages to fract...
# 21                              Divide decimals by 10
# 22                              Divide decimals by 10
# 23                              Divide decimals by 10
# 24  Subtract proper fractions with different denom...
# 25  Subtract proper fractions with different denom...
# 26  Subtract proper fractions with different denom...
# 27  Identify horizontal translations in the form f...
# 28  Identify horizontal translations in the form f...
# 29  Identify horizontal translations in the form f...
# 30  Expand products of three binomials in the form...
# 31  Expand products of three binomials in the form...
# 32  Expand products of three binomials in the form...
# 33                    Identify the net of a non-prism
# 34                    Identify the net of a non-prism
# 35                    Identify the net of a non-prism
# 36                          Identify alternate angles
# 37                          Identify alternate angles
# 38                          Identify alternate angles
# 39                      Convert from hours to minutes
# 40                      Convert from hours to minutes
# 41                      Convert from hours to minutes
# 42  Select the correct answer to an iteration ques...
# 43  Select the correct answer to an iteration ques...
# 44  Select the correct answer to an iteration ques...
# 45  Calculate the area of an equilateral triangle ...
# 46  Calculate the area of an equilateral triangle ...
# 47  Calculate the area of an equilateral triangle ...
# 48  Divide a quantity into two parts for a given a...
# 49  Divide a quantity into two parts for a given a...
#
#                                           SubjectName  \
# 0                                              BIDMAS
# 1                                              BIDMAS
# 2                                              BIDMAS
# 3                     Simplifying Algebraic Fractions
# 4                     Simplifying Algebraic Fractions
# 5                     Simplifying Algebraic Fractions
# 6   Range and Interquartile Range from a List of Data
# 7   Range and Interquartile Range from a List of Data
# 8   Range and Interquartile Range from a List of Data
# 9                        Properties of Quadrilaterals
# 10                       Properties of Quadrilaterals
# 11                       Properties of Quadrilaterals
# 12                          Substitution into Formula
# 13                          Substitution into Formula
# 14                          Substitution into Formula
# 15                              Area of Simple Shapes
# 16                              Area of Simple Shapes
# 17                              Area of Simple Shapes
# 18       Converting between Fractions and Percentages
# 19       Converting between Fractions and Percentages
# 20       Converting between Fractions and Percentages
# 21             Multiplying and Dividing with Decimals
# 22             Multiplying and Dividing with Decimals
# 23             Multiplying and Dividing with Decimals
# 24                   Adding and Subtracting Fractions
# 25                   Adding and Subtracting Fractions
# 26                   Adding and Subtracting Fractions
# 27      Transformations of functions in the form f(x)
# 28      Transformations of functions in the form f(x)
# 29      Transformations of functions in the form f(x)
# 30                 Expanding Triple Brackets and more
# 31                 Expanding Triple Brackets and more
# 32                 Expanding Triple Brackets and more
# 33                                               Nets
# 34                                               Nets
# 35                                               Nets
# 36                    Angle Facts with Parallel Lines
# 37                    Angle Facts with Parallel Lines
# 38                    Angle Facts with Parallel Lines
# 39                                               Time
# 40                                               Time
# 41                                               Time
# 42        Trial and Improvement and Iterative Methods
# 43        Trial and Improvement and Iterative Methods
# 44        Trial and Improvement and Iterative Methods
# 45                              Area of Simple Shapes
# 46                              Area of Simple Shapes
# 47                              Area of Simple Shapes
# 48                                 Sharing in a Ratio
# 49                                 Sharing in a Ratio
#
#                                          QuestionText  \
# 0   \[\n3 \times 2+4-5\n\]\nWhere do the brackets ...
# 1   \[\n3 \times 2+4-5\n\]\nWhere do the brackets ...
# 2   \[\n3 \times 2+4-5\n\]\nWhere do the brackets ...
# 3   Simplify the following, if possible: \( \frac{...
# 4   Simplify the following, if possible: \( \frac{...
# 5   Simplify the following, if possible: \( \frac{...
# 6   Tom and Katie are discussing the \( 5 \) plant...
# 7   Tom and Katie are discussing the \( 5 \) plant...
# 8   Tom and Katie are discussing the \( 5 \) plant...
# 9   The angles highlighted on this rectangle with ...
# 10  The angles highlighted on this rectangle with ...
# 11  The angles highlighted on this rectangle with ...
# 12  The equation \( f=3 r^{2}+3 \) is used to find...
# 13  The equation \( f=3 r^{2}+3 \) is used to find...
# 14  The equation \( f=3 r^{2}+3 \) is used to find...
# 15  James has answered a question on the area of a...
# 16  James has answered a question on the area of a...
# 17  James has answered a question on the area of a...
# 18  Convert this percentage to a fraction\n\( 62 \...
# 19  Convert this percentage to a fraction\n\( 62 \...
# 20  Convert this percentage to a fraction\n\( 62 \...
# 21                                \( 43.2 \div 10= \)
# 22                                \( 43.2 \div 10= \)
# 23                                \( 43.2 \div 10= \)
# 24  \(\n\frac{4}{5}-\frac{1}{3}=\frac{\bigstar}{15...
# 25  \(\n\frac{4}{5}-\frac{1}{3}=\frac{\bigstar}{15...
# 26  \(\n\frac{4}{5}-\frac{1}{3}=\frac{\bigstar}{15...
# 27  What transformation maps the graph of\n\(y=f(x...
# 28  What transformation maps the graph of\n\(y=f(x...
# 29  What transformation maps the graph of\n\(y=f(x...
# 30  John is expanding these three brackets:\n\(\n(...
# 31  John is expanding these three brackets:\n\(\n(...
# 32  John is expanding these three brackets:\n\(\n(...
# 33  This is the net of a... ![A circle touching a ...
# 34  This is the net of a... ![A circle touching a ...
# 35  This is the net of a... ![A circle touching a ...
# 36  Tom and Katie are arguing about alternate angl...
# 37  Tom and Katie are arguing about alternate angl...
# 38  Tom and Katie are arguing about alternate angl...
# 39  Hannah's journey to camp is \( 3 \) hours and ...
# 40  Hannah's journey to camp is \( 3 \) hours and ...
# 41  Hannah's journey to camp is \( 3 \) hours and ...
# 42  \(\nx_{n+1}=5-\frac{1}{x_{n}}\n\)\n\nUsing a s...
# 43  \(\nx_{n+1}=5-\frac{1}{x_{n}}\n\)\n\nUsing a s...
# 44  \(\nx_{n+1}=5-\frac{1}{x_{n}}\n\)\n\nUsing a s...
# 45  How would you calculate the area of this trian...
# 46  How would you calculate the area of this trian...
# 47  How would you calculate the area of this trian...
# 48  In the diagram, AN : NB \( =3: 5 \) \nWhat is ...
# 49  In the diagram, AN : NB \( =3: 5 \) \nWhat is ...
#
#                                        correct_answer  \
# 0                               \( 3 \times(2+4)-5 \)
# 1                               \( 3 \times(2+4)-5 \)
# 2                               \( 3 \times(2+4)-5 \)
# 3                                   Does not simplify
# 4                                   Does not simplify
# 5                                   Does not simplify
# 6                                         Only\nKatie
# 7                                         Only\nKatie
# 8                                         Only\nKatie
# 9                                    \( 90^{\circ} \)
# 10                                   \( 90^{\circ} \)
# 11                                   \( 90^{\circ} \)
# 12                                           \( 30 \)
# 13                                           \( 30 \)
# 14                                           \( 30 \)
# 15                              \( \mathrm{mm}^{2} \)
# 16                              \( \mathrm{mm}^{2} \)
# 17                              \( \mathrm{mm}^{2} \)
# 18                                \( \frac{31}{50} \)
# 19                                \( \frac{31}{50} \)
# 20                                \( \frac{31}{50} \)
# 21                                         \( 4.32 \)
# 22                                         \( 4.32 \)
# 23                                         \( 4.32 \)
# 24                                            \( 7 \)
# 25                                            \( 7 \)
# 26                                            \( 7 \)
# 27  Translation by vector\n\(\n\left[\begin{array}...
# 28  Translation by vector\n\(\n\left[\begin{array}...
# 29  Translation by vector\n\(\n\left[\begin{array}...
# 30  \( \begin{array}{l}+6 x^{2} \\ -3 x^{2} \\ +5 ...
# 31  \( \begin{array}{l}+6 x^{2} \\ -3 x^{2} \\ +5 ...
# 32  \( \begin{array}{l}+6 x^{2} \\ -3 x^{2} \\ +5 ...
# 33                                               Cone
# 34                                               Cone
# 35                                               Cone
# 36                                          Only\nTom
# 37                                          Only\nTom
# 38                                          Only\nTom
# 39                                   \( 18 \) minutes
# 40                                   \( 18 \) minutes
# 41                                   \( 18 \) minutes
# 42                                         \( 4.79 \)
# 43                                         \( 4.79 \)
# 44                                         \( 4.79 \)
# 45                                      None of these
# 46                                      None of these
# 47                                      None of these
# 48                               \( 18 \mathrm{~m} \)
# 49                               \( 18 \mathrm{~m} \)
#
#                                      incorrect_answer
# 0                              \( 3 \times 2+(4-5) \)
# 1                               \( 3 \times(2+4-5) \)
# 2                              Does not need brackets
# 3                                           \( m+1 \)
# 4                                           \( m+2 \)
# 5                                           \( m-1 \)
# 6                                           Only\nTom
# 7                                  Both Tom and Katie
# 8                                  Neither is correct
# 9                                               acute
# 10                                             obtuse
# 11                             Not enough information
# 12                                           \( 27 \)
# 13                                           \( 51 \)
# 14                                           \( 24 \)
# 15                                            \( m \)
# 16                                  \( \mathrm{cm} \)
# 17                              \( \mathrm{km}^{3} \)
# 18                                \( \frac{62}{10} \)
# 19                                  \( \frac{6}{2} \)
# 20                                      None of these
# 21                                        \( 0.432 \)
# 22                                         \( 33.2 \)
# 23                                        \( 43.02 \)
# 24                                            \( 5 \)
# 25                                           \( 17 \)
# 26                                            \( 3 \)
# 27  Translation by vector\n\(\n\left[\begin{array}...
# 28  Translation by vector\n\(\n\left[\begin{array}...
# 29  Translation by vector\n\(\n\left[\begin{array}...
# 30                                     \( +6 x^{2} \)
# 31  \( \begin{array}{l}+6 x^{2} \\ +3 x^{2} \\ +5 ...
# 32  \( \begin{array}{l}+6 x^{2} \\ -3 x^{2} \\ -5 ...
# 33                                           Triangle
# 34                                   Triangular prism
# 35                            Triangularbased pyramid
# 36                                        Only\nKatie
# 37                                 Both Tom and Katie
# 38                                 Neither is correct
# 39                                  \( 196 \) minutes
# 40                                  \( 102 \) minutes
# 41                                   \( 12 \) minutes
# 42                                         \( 4.78 \)
# 43                               \( 4.79128 \ldots \)
# 44                                          \( 4.8 \)
# 45                        \( \frac{6 \times 12}{2} \)
# 46                       \( \frac{12 \times 12}{2} \)
# 47             \( \frac{12 \times 12 \times 12}{2} \)
# 48                               \( 16 \mathrm{~m} \)
# 49                               \( 30 \mathrm{~m} \)

# %%
import torch
from numpy.linalg import norm
import torch.nn.functional as F
from torch import Tensor
from transformers import AutoTokenizer, AutoModel,BitsAndBytesConfig
from peft import (
    LoraConfig,
    get_peft_model,
)

def batch_to_device(batch, target_device):
    """
    send a pytorch batch to a device (CPU/GPU)
    """
    for key in batch:
        if isinstance(batch[key], Tensor):
            batch[key] = batch[key].to(target_device)
    return batch

def last_token_pool(last_hidden_states: Tensor,
                    attention_mask: Tensor) -> Tensor:
    left_padding = (attention_mask[:, -1].sum() == attention_mask.shape[0])
    if left_padding:
        return last_hidden_states[:, -1]
    else:
        sequence_lengths = attention_mask.sum(dim=1) - 1
        batch_size = last_hidden_states.shape[0]
        return last_hidden_states[torch.arange(batch_size, device=last_hidden_states.device), sequence_lengths]

def get_detailed_instruct(task_description: str, query: str) -> str:
    return f'Instruct: {task_description}\nQuery: {query}'

def inference(df, model, tokenizer, device):
    batch_size = 16
    max_length = 512
    sentences = list(df['query_text'].values)

    all_embeddings = []
    length_sorted_idx = np.argsort([-len(sen) for sen in sentences])
    sentences_sorted = [sentences[idx] for idx in length_sorted_idx]
    for start_index in trange(0, len(sentences), batch_size, desc="Batches", disable=False):
        sentences_batch = sentences_sorted[start_index: start_index + batch_size]
        features = tokenizer(sentences_batch, max_length=max_length, padding=True, truncation=True,
                             return_tensors="pt")
        features = batch_to_device(features, device)
        with torch.no_grad():
            outputs = model.model(**features)
            embeddings = last_token_pool(outputs.last_hidden_state, features['attention_mask'])
            embeddings = torch.nn.functional.normalize(embeddings, dim=-1)
            embeddings = embeddings.detach().cpu().numpy().tolist()
        all_embeddings.extend(embeddings)

    all_embeddings = [np.array(all_embeddings[idx]).reshape(1, -1) for idx in np.argsort(length_sorted_idx)]

    return np.concatenate(all_embeddings, axis=0)

# %%
path_prefix = "/kaggle/input/eedi-mining-misconceptions-in-mathematics"
model_path = "/kaggle/input/sfr-embedding-mistral/SFR-Embedding-2_R"
lora_path="/kaggle/input/v7-recall/epoch_19_model/adapter.bin"
device='cuda:0'

# %%
tokenizer = AutoTokenizer.from_pretrained(lora_path.replace("/adapter.bin",""))
bnb_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_use_double_quant=True,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_compute_dtype=torch.bfloat16
        )
backbone = AutoModel.from_pretrained(model_path, quantization_config=bnb_config,device_map=device)
config = LoraConfig(
        r=64,
        lora_alpha=128,
        target_modules=[
            "q_proj",
            "k_proj",
            "v_proj",
            "o_proj",
            "gate_proj",
            "up_proj",
            "down_proj",
        ],
        bias="none",
        lora_dropout=0.05,  # Conventional
        task_type="CAUSAL_LM",
    )
model = get_peft_model(backbone, config)
d = torch.load(lora_path, map_location=model.device)
model.load_state_dict(d, strict=False)
model = model.eval()
model = model.to(device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tokenizer = AutoTokenizer.from_pretrained(lora_path.replace("/adapter.bin",""))
#       2 bnb_config = BitsAndBytesConfig(
#       3             load_in_4bit=True,
#       4             bnb_4bit_use_double_quant=True,
#       5             bnb_4bit_quant_type="nf4",
#       6             bnb_4bit_compute_dtype=torch.bfloat16
#       7         )
#       8 backbone = AutoModel.from_pretrained(model_path, quantization_config=bnb_config,device_map=device)
#
# NameError: name 'lora_path' is not defined

# %%
import numpy as np
from tqdm.autonotebook import trange


task_description = 'Given a math question and a misconcepte incorrect answer, please retrieve the most accurate reason for the misconception.'


V_answer = inference(df, model, tokenizer, device)

misconception_df = pd.read_csv("/kaggle/input/eedi-mining-misconceptions-in-mathematics/misconception_mapping.csv")
misconception_df["query_text"] = misconception_df["MisconceptionName"]

V_misconception = inference(misconception_df, model, tokenizer, device)
V_misconception.shape
# Out:
# Batches:   0%|          | 0/351 [00:00<?, ?it/s]

# %%
from transformers import AutoConfig, AutoTokenizer, AutoModelForMaskedLM, AutoModel
import sys, os
from tqdm import tqdm
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn.functional as F
import torch.nn as nn
import math
from sklearn.neighbors import NearestNeighbors


os.environ["TOKENIZERS_PARALLELISM"] = "false"

def get_matches(V_topic, V_content, n_neighbors=25):
    
    neighbors_model = NearestNeighbors(n_neighbors=n_neighbors, metric='cosine', algorithm="brute", n_jobs=-1)
    neighbors_model.fit(V_content)
    dists, indices = neighbors_model.kneighbors(V_topic)
    
    return indices

indices = get_matches(V_answer, V_misconception, n_neighbors=25)
indices.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 26
#      22     dists, indices = neighbors_model.kneighbors(V_topic)
#      24     return indices
# ---> 26 indices = get_matches(V_answer, V_misconception, n_neighbors=25)
#      27 indices.shape
#
# NameError: name 'V_answer' is not defined

# %%
import gc

del backbone, model

gc.collect()
torch.cuda.empty_cache()

# %%
np.save("indices.npy", indices)
df.to_parquet("df.parquet", index=False)

# %% [markdown]
# # Picking the best candidate using qwen-32b-instruct-awq
# Inspired by: https://www.kaggle.com/code/takanashihumbert/eedi-qwen-2-5-32b-awq-two-time-retrieval

# %% [markdown]
# ## Using MultipleChoiceLogitsProcessor from logits-processor-zoo

# %% [markdown]
# <p align="center">
#     <img src="https://raw.githubusercontent.com/NVIDIA/logits-processor-zoo/refs/heads/main/docs/logo.jpg" width="512">
# </p>
#
# # logits-processor-zoo
#
# Struggling to get LLMs to follow your instructions? LogitsProcessorZoo offers a zoo of tools to use LLMs for specific tasks, beyond just grammar enforcement!
#
# ## Installation
#
# ```bash
# pip install logits-processor-zoo
# ```
#
# ## Supported Frameworks
# * transformers
# * vLLM
# * TensorRT-LLM
#
#
# For the detailed examples in each framework, please have a look at **example_notebook** directory.
#
# ## Available Logits Processors
#
# ### GenLengthLogitsProcessor
# A logits processor that adjusts the likelihood of the end-of-sequence (EOS) token based on the length of the generated sequence, encouraging or discouraging shorter answers.
#
# ### CiteFromPromptLogitsProcessor
# A logits processor which boosts or diminishes the likelihood of tokens present in the prompt (and optionally EOS token) to encourage the model to generate tokens similar to those seen in the prompt or vice versa.
#
# ### ForceLastPhraseLogitsProcessor
# A logits processor which forces LLMs to use the given phrase before they finalize their answers. Most common use cases can be providing references, thanking user with context etc.
#
# ### MultipleChoiceLogitsProcessor
# A logits processor to answer multiple choice questions with one of the choices. A multiple choice question is like:
# ```
# I am getting a lot of calls during the day. What is more important for me to consider when I buy a new phone?
# 0. Camera
# 1. Screen resolution
# 2. Operating System
# 3. Battery
# ```
# The goal is to make LLM generate "3" as an answer.

# %%
# %%writefile run_vllm.py

import vllm
import numpy as np
import pandas as pd
from transformers import PreTrainedTokenizer, AutoTokenizer
from typing import List
import torch
from logits_processor_zoo.vllm import MultipleChoiceLogitsProcessor
import re

model_path = "/kaggle/input/qwen2.5/transformers/32b-instruct-awq/1"
tokenizer = AutoTokenizer.from_pretrained(model_path)


def preprocess_text(x):
    x = re.sub("http\w+", '',x)   # Delete URL
    x = re.sub(r"\.+", ".", x)    # Replace consecutive commas and periods with one comma and period character
    x = re.sub(r"\,+", ",", x)
    x = re.sub(r"\\\(", " ", x)
    x = re.sub(r"\\\)", " ", x)
    x = re.sub(r"[ ]{1,}", " ", x)
    x = x.strip()                 # Remove empty characters at the beginning and end
    return x

PROMPT  = """Here is a question about {ConstructName}({SubjectName}).
Question: {Question}
Correct Answer: {CorrectAnswer}
Incorrect Answer: {IncorrectAnswer}

You are a Mathematics teacher. Your task is to reason and identify the misconception behind the Incorrect Answer with the Question.
Answer concisely what misconception it is to lead to getting the incorrect answer.
Pick the correct misconception number from the below:

{Retrival}
"""
# just directly give your answers.

def apply_template(row, tokenizer):
    messages = [
        {
            "role": "user", 
            "content": preprocess_text(
                PROMPT.format(
                    ConstructName=row["ConstructName"],
                    SubjectName=row["SubjectName"],
                    Question=row["QuestionText"],
                    IncorrectAnswer=row[f"incorrect_answer"],
                    CorrectAnswer=row[f"correct_answer"],
                    Retrival=row[f"retrieval"]
                )
            )
        }
    ]
    text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    return text


misconception_df = pd.read_csv("/kaggle/input/eedi-mining-misconceptions-in-mathematics/misconception_mapping.csv")

df = pd.read_parquet("df.parquet")
indices = np.load("indices.npy")

model_path = "/kaggle/input/qwen2.5/transformers/32b-instruct-awq/1"

llm = vllm.LLM(
    model_path,
    quantization="awq",
    tensor_parallel_size=2,
    gpu_memory_utilization=0.90, 
    trust_remote_code=True,
    dtype="half", 
    enforce_eager=True,
    max_model_len=5120,
    disable_log_stats=True
)
tokenizer = llm.get_tokenizer()


def get_candidates(c_indices):
    candidates = []

    mis_names = misconception_df["MisconceptionName"].values
    for ix in c_indices:
        c_names = []
        for i, name in enumerate(mis_names[ix]):
            c_names.append(f"{i+1}. {name}")

        candidates.append("\n".join(c_names))
        
    return candidates

survivors = indices[:, -1:]

for i in range(3):
    c_indices = np.concatenate([indices[:, -8*(i+1)-1:-8*i-1], survivors], axis=1)
    
    df["retrieval"] = get_candidates(c_indices)
    df["text"] = df.apply(lambda row: apply_template(row, tokenizer), axis=1)
    
    print("Example:")
    print(df["text"].values[0])
    print()
    
    responses = llm.generate(
        df["text"].values,
        vllm.SamplingParams(
            n=1,  # Number of output sequences to return for each prompt.
            top_k=1,  # Float that controls the cumulative probability of the top tokens to consider.
            temperature=0,  # randomness of the sampling
            seed=777, # Seed for reprodicibility
            skip_special_tokens=False,  # Whether to skip special tokens in the output.
            max_tokens=1,  # Maximum number of tokens to generate per output sequence.
            logits_processors=[MultipleChoiceLogitsProcessor(tokenizer, choices=["1", "2", "3", "4", "5", "6", "7", "8", "9"])]
        ),
        use_tqdm=True
    )
    
    responses = [x.outputs[0].text for x in responses]
    df["response"] = responses
    
    
    llm_choices = df["response"].astype(int).values - 1
    
    survivors = np.array([cix[best] for best, cix in zip(llm_choices, c_indices)]).reshape(-1, 1)



results = []

for i in range(indices.shape[0]):
    ix = indices[i]
    llm_choice = survivors[i, 0]
    
    results.append(" ".join([str(llm_choice)] + [str(x) for x in ix if x != llm_choice]))


df["MisconceptionId"] = results
df.to_csv("submission.csv", columns=["QuestionId_Answer", "MisconceptionId"], index=False)
# Out:
# Overwriting run_vllm.py

# %%
# !python run_vllm.py
# Out:
# Traceback (most recent call last):
#   File "/kaggle/working/run_vllm.py", line 2, in <module>
#     import vllm
# ModuleNotFoundError: No module named 'vllm'
